# %%
import numpy as np
import pandas as pd

# %%
iris = pd.read_csv("../Datasets/iris-data.csv")
iris2 = pd.read_csv("../Datasets/iris.csv")

# %%
iris.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
iris
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# 5                5.4             3.9              1.7             0.4
# 6                4.6             3.4              1.4             0.3
# 7                5.0             3.4              1.5             NaN
# 8                4.4             2.9              1.4             NaN
# 9                4.9             3.1              1.5             NaN
# 10               5.4             3.7              1.5             NaN
# 11               4.8             3.4              1.6             NaN
# ...

# %%
print(iris.to_string())
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm            class
# 0              5.100             3.5              1.4             0.2      Iris-setosa
# 1              4.900             3.0              1.4             0.2      Iris-setosa
# 2              4.700             3.2              1.3             0.2      Iris-setosa
# 3              4.600             3.1              1.5             0.2      Iris-setosa
# 4              5.000             3.6              1.4             0.2      Iris-setosa
# 5              5.400             3.9              1.7             0.4      Iris-setosa
# 6              4.600             3.4              1.4             0.3      Iris-setosa
# 7              5.000             3.4              1.5             NaN      Iris-setosa
# 8              4.400             2.9              1.4             NaN      Iris-setosa
# 9              4.900             3.1              1.5             NaN      Iris-setosa
# ...

# %%
iris.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
iris['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'versicolor',
#        'Iris-virginica'], dtype=object)

# %%
#Analysing records we can see class labels are wrong in a few records
#Iris-setosa has been erroneously writen as Iris-setossa, and Iris-versicolor has been named versicolor in 5 records.
#Fixing this, we have -
iris.loc[iris['class']=='versicolor','class']='Iris-versicolor'
iris.loc[iris['class']=='Iris-setossa','class']='Iris-setosa'

# %%
print(iris.to_string())
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm            class
# 0              5.100             3.5              1.4             0.2      Iris-setosa
# 1              4.900             3.0              1.4             0.2      Iris-setosa
# 2              4.700             3.2              1.3             0.2      Iris-setosa
# 3              4.600             3.1              1.5             0.2      Iris-setosa
# 4              5.000             3.6              1.4             0.2      Iris-setosa
# 5              5.400             3.9              1.7             0.4      Iris-setosa
# 6              4.600             3.4              1.4             0.3      Iris-setosa
# 7              5.000             3.4              1.5             NaN      Iris-setosa
# 8              4.400             2.9              1.4             NaN      Iris-setosa
# 9              4.900             3.1              1.5             NaN      Iris-setosa
# ...

# %%
iris['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris.isnull().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     5
# class              0
# dtype: int64

# %%
means = iris.groupby('class')['petal_width_cm'].mean()
print(means)
m = means['Iris-setosa']
# Out:
# class
# Iris-setosa        0.251111
# Iris-versicolor    1.326000
# Iris-virginica     2.034000
# Name: petal_width_cm, dtype: float64

# %%
iris = iris.fillna(m)
iris
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4        0.200000
# 1                4.9             3.0              1.4        0.200000
# 2                4.7             3.2              1.3        0.200000
# 3                4.6             3.1              1.5        0.200000
# 4                5.0             3.6              1.4        0.200000
# 5                5.4             3.9              1.7        0.400000
# 6                4.6             3.4              1.4        0.300000
# 7                5.0             3.4              1.5        0.251111
# 8                4.4             2.9              1.4        0.251111
# 9                4.9             3.1              1.5        0.251111
# 10               5.4             3.7              1.5        0.251111
# 11               4.8             3.4              1.6        0.251111
# ...

# %%
get_ipython().magic('matplotlib inline')
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
import seaborn as sb

# %%
heat = sb.heatmap(iris.corr(),annot=True, fmt='.2f')

# %%
#s = sb.pairplot(iris, hue="class")
sb.pairplot(iris.dropna(),height = 3,vars=["sepal_length_cm","sepal_width_cm","petal_length_cm","petal_width_cm"],hue="class",palette="husl")
#plots all features against other features in scatter and histogram plots

# %%
sb.pairplot(iris.dropna(),height = 3, vars=["sepal_width_cm", "sepal_length_cm"], hue = 'class',palette="husl")

# %%
sb.pairplot(iris.dropna(), height = 3, x_vars=["sepal_width_cm", "sepal_length_cm"],y_vars=["petal_width_cm", "petal_length_cm"], hue = 'class',palette="husl")

# %%
sb.pairplot(iris.dropna(), height=3, vars=["petal_width_cm", "petal_length_cm"],hue='class',palette="husl")

# %%
#cleaning data
iris.loc[iris['class']=='Iris-setosa','class']=1
iris.loc[iris['class']=='Iris-versicolor','class']=2
iris.loc[iris['class']=='Iris-virginica','class']=3

# %%
iris
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  class
# 0                5.1             3.5              1.4        0.200000      1
# 1                4.9             3.0              1.4        0.200000      1
# 2                4.7             3.2              1.3        0.200000      1
# 3                4.6             3.1              1.5        0.200000      1
# 4                5.0             3.6              1.4        0.200000      1
# 5                5.4             3.9              1.7        0.400000      1
# 6                4.6             3.4              1.4        0.300000      1
# 7                5.0             3.4              1.5        0.251111      1
# 8                4.4             2.9              1.4        0.251111      1
# 9                4.9             3.1              1.5        0.251111      1
# 10               5.4             3.7              1.5        0.251111      1
# ...

# %%
temp1 = iris.groupby('sepal_width_cm').count()
temp1
# Out:
#                 sepal_length_cm  petal_length_cm  petal_width_cm  class
# sepal_width_cm
# 2.0                           1                1               1      1
# 2.2                           3                3               3      3
# 2.3                           4                4               4      4
# 2.4                           3                3               3      3
# 2.5                           8                8               8      8
# 2.6                           5                5               5      5
# 2.7                           8                8               8      8
# 2.8                          15               15              15     15
# 2.9                          10               10              10     10
# 3.0                          26               26              26     26
# 3.1                          12               12              12     12
# 3.2                          13               13              13     13
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
iris.hist(column=['petal_width_cm','sepal_width_cm'],bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a21d3c3c8>,
# ...
#       dtype=object)

# %%
pkmn = pd.read_csv("../Datasets/Pokemon.csv")
pkmn['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
pkmn.loc[pkmn['Type 1']=='Grass','Type 1']=1
pkmn.loc[pkmn['Type 1']=='Fire','Type 1']=2
pkmn.loc[pkmn['Type 1']=='Water','Type 1']=3
pkmn.loc[pkmn['Type 1']=='Bug','Type 1']=4
pkmn.loc[pkmn['Type 1']=='Normal','Type 1']=5
pkmn.loc[pkmn['Type 1']=='Poison','Type 1']=6
pkmn.loc[pkmn['Type 1']=='Electric','Type 1']=7
pkmn.loc[pkmn['Type 1']=='Fairy','Type 1']=8
pkmn.loc[pkmn['Type 1']=='Fighting','Type 1']=9
pkmn.loc[pkmn['Type 1']=='Psychic','Type 1']=10
pkmn.loc[pkmn['Type 1']=='Rock','Type 1']=11
pkmn.loc[pkmn['Type 1']=='Ghost','Type 1']=12
pkmn.loc[pkmn['Type 1']=='Ice','Type 1']=13
pkmn.loc[pkmn['Type 1']=='Dragon','Type 1']=14
pkmn.loc[pkmn['Type 1']=='Dark','Type 1']=15
pkmn.loc[pkmn['Type 1']=='Steel','Type 1']=16
pkmn.loc[pkmn['Type 1']=='Flying','Type 1']=17
pkmn.loc[pkmn['Type 2']=='Ground','Type 2']=19

# %%
pkmn.loc[pkmn['Type 2']=='Grass','Type 2']=1
pkmn.loc[pkmn['Type 2']=='Fire','Type 2']=2
pkmn.loc[pkmn['Type 2']=='Water','Type 2']=3
pkmn.loc[pkmn['Type 2']=='Bug','Type 2']=4
pkmn.loc[pkmn['Type 2']=='Normal','Type 2']=5
pkmn.loc[pkmn['Type 2']=='Poison','Type 2']=6
pkmn.loc[pkmn['Type 2']=='Electric','Type 2']=7
pkmn.loc[pkmn['Type 2']=='Fairy','Type 2']=8
pkmn.loc[pkmn['Type 2']=='Fighting','Type 2']=9
pkmn.loc[pkmn['Type 2']=='Psychic','Type 2']=10
pkmn.loc[pkmn['Type 2']=='Rock','Type 2']=11
pkmn.loc[pkmn['Type 2']=='Ghost','Type 2']=12
pkmn.loc[pkmn['Type 2']=='Ice','Type 2']=13
pkmn.loc[pkmn['Type 2']=='Dragon','Type 2']=14
pkmn.loc[pkmn['Type 2']=='Dark','Type 2']=15
pkmn.loc[pkmn['Type 2']=='Steel','Type 2']=16
pkmn.loc[pkmn['Type 2']=='Flying','Type 2']=17
pkmn.loc[pkmn['Type 2']=='Ground','Type 2']=18

# %%
pkmn.loc[pkmn['Legendary']==False,'Legendary']=0
pkmn.loc[pkmn['Legendary']==True,'Legendary']=1
pkmn
# Out:
#        #                       Name Type 1 Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur      1      6    318   45      49
# 1      2                    Ivysaur      1      6    405   60      62
# 2      3                   Venusaur      1      6    525   80      82
# 3      3      VenusaurMega Venusaur      1      6    625   80     100
# 4      4                 Charmander      2    NaN    309   39      52
# 5      5                 Charmeleon      2    NaN    405   58      64
# 6      6                  Charizard      2     17    534   78      84
# 7      6  CharizardMega Charizard X      2     14    634   78     130
# 8      6  CharizardMega Charizard Y      2     17    634   78     104
# 9      7                   Squirtle      3    NaN    314   44      48
# 10     8                  Wartortle      3    NaN    405   59      63
# 11     9                  Blastoise      3    NaN    530   79      83
# ...

# %%
pkmn = pkmn.drop(['#','Name'],axis=1)
pkmn.isnull().sum()
# Out:
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pkmn = pkmn.fillna(0)
pkmn.dtypes
# Out:
# Type 1        object
# Type 2         int64
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary      int64
# dtype: object

# %%
pkmn.isnull().sum()
# Out:
# Type 1        0
# Type 2        0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
pkmn['Type 2'].mean()
# Out:
# 6.04875

# %%
pkmn_1 = pkmn.loc[(pkmn['Generation']==1) | (pkmn['Generation']==2)]

# %%
s = sb.pairplot(pkmn_1, hue="Legendary",height = 3,vars=["HP","Attack","Defense","Sp. Atk", "Sp. Def"],palette="husl")

# %%
heat = sb.heatmap(pkmn.corr(),annot=True, fmt='.2f')

# %%
pkmn
# Out:
#     Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0        1       6    318   45      49       49       65       65     45
# 1        1       6    405   60      62       63       80       80     60
# 2        1       6    525   80      82       83      100      100     80
# 3        1       6    625   80     100      123      122      120     80
# 4        2       0    309   39      52       43       60       50     65
# 5        2       0    405   58      64       58       80       65     80
# 6        2      17    534   78      84       78      109       85    100
# 7        2      14    634   78     130      111      130       85    100
# 8        2      17    634   78     104       78      159      115    100
# 9        3       0    314   44      48       65       50       64     43
# 10       3       0    405   59      63       80       65       80     58
# 11       3       0    530   79      83      100       85      105     78
# ...
