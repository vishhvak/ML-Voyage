# %%
import pandas as pd
import numpy as np
import sklearn

# %%
cols = ["Age","Spectacles Prescription","Astigmatic","TPR","Target"]
lens = pd.read_csv("../Datasets/lenses.csv",names = cols)

# %%
lens
# Out:
#     Age  Spectacles Prescription  Astigmatic  TPR  Target
# 1     1                        1           1    1       3
# 2     1                        1           1    2       2
# 3     1                        1           2    1       3
# 4     1                        1           2    2       1
# 5     1                        2           1    1       3
# 6     1                        2           1    2       2
# 7     1                        2           2    1       3
# 8     1                        2           2    2       1
# 9     2                        1           1    1       3
# 10    2                        1           1    2       2
# 11    2                        1           2    1       3
# 12    2                        1           2    2       1
# 13    2                        2           1    1       3
# 14    2                        2           1    2       2
# 15    2                        2           2    1       3
# ...

# %%
lens.describe()
# Out:
#              Age  Spectacles Prescription  Astigmatic        TPR     Target
# count  24.000000                24.000000   24.000000  24.000000  24.000000
# mean    2.000000                 1.500000    1.500000   1.500000   2.458333
# std     0.834058                 0.510754    0.510754   0.510754   0.779028
# min     1.000000                 1.000000    1.000000   1.000000   1.000000
# 25%     1.000000                 1.000000    1.000000   1.000000   2.000000
# 50%     2.000000                 1.500000    1.500000   1.500000   3.000000
# 75%     3.000000                 2.000000    2.000000   2.000000   3.000000
# max     3.000000                 2.000000    2.000000   2.000000   3.000000

# %%
lens.head()
# Out:
#    Age  Spectacles Prescription  Astigmatic  TPR  Target
# 1    1                        1           1    1       3
# 2    1                        1           1    2       2
# 3    1                        1           2    1       3
# 4    1                        1           2    2       1
# 5    1                        2           1    1       3

# %%
import seaborn as sb
